# %%
import pandas as pd

# %%
data1 = pd.read_csv('data/양적관점df.csv')

# %%
data2 = pd.read_csv('data/질적관점df.csv')

# %%
data1
# Out:
#       지역     1인/가구당     2인/가구당     3인/가구당     4인/가구당    5인/가구당    6인/가구당  \
# 0    가평군  33.271315  32.725287  17.541660  10.948876  3.971849  1.132503
# 1    고양시  22.856842  25.887038  24.452592  20.772585  4.746723  1.026187
# 2    과천시  18.240711  24.461934  25.784345  24.167470  5.867866  1.054717
# 3    광명시  22.068394  26.038126  24.238594  21.611465  4.851989  0.966811
# 4    광주시  22.625609  28.609487  23.278271  18.831774  5.124349  1.156471
# 5    구리시  22.151265  25.447311  24.428862  21.721346  4.929460  1.042101
# 6    군포시  21.807390  25.540880  24.452030  22.106191  4.890203  0.924763
# 7    김포시  21.525897  26.202163  23.991663  21.512998  5.284561  1.167030
# 8   남양주시  19.101857  26.573640  24.359206  22.261162  5.940233  1.367916
# 9   동두천시  29.197335  30.129479  19.865148  14.933111  4.445817  1.117499
# 10   부천시  24.800557  25.699976  23.752677  20.043736  4.535893  0.923147
# 11   성남시  28.635875  24.970639  22.359611  18.626747  4.243548  0.918118
# ...

# %%
data2
# Out:
#         신고시각  귀소까지시간  현장과의거리  의식상태 긴급구조구     가중치
# 0        1.2     1.0     1.2   1.0   수원시  1.4400
# 1        1.2     1.0     1.0   1.2   수원시  1.4400
# 2        1.2     1.0     1.0   1.2   수원시  1.4400
# 3        1.2     1.0     1.2   1.2   안산시  1.7280
# 4        1.0     1.0     1.0   1.2   군포시  1.2000
# ...      ...     ...     ...   ...   ...     ...
# 481521   1.0     1.2     1.0   1.0   안산시  1.2000
# 481522   1.2     1.0     1.0   1.2   부천시  1.4400
# 481523   1.2     1.0     1.2   1.0  남양주시  1.4400
# 481524   1.2     1.2     1.2   1.2   평택시  2.0736
# 481525   1.2     1.0     1.0   1.2   용인시  1.4400
#
# [481526 rows x 6 columns]

# %%
data3 = pd.read_csv('data/소방청_구급활동현황_20181231.csv', encoding='euc-kr')

# %%
data3[160000:160005]
# Out:
#         집계년도      시군명    출동소방서 출동안전센터_지역대       신고년월일   신고시각  접수경로 관할구분  \
# 160000  2018  수원시 팔달구  수원남부소방서  지만119안전센터  2018-02-17  17:00  휴대전화  센터외
# 160001  2018  수원시 영통구    수원소방서  영통119안전센터  2018-02-17  15:18  휴대전화   센터
# 160002  2018      광명시    광명소방서  광남119안전센터  2018-02-18  09:21  휴대전화   센터
# 160003  2018      시흥시    시흥소방서  시흥119안전센터  2018-02-16  21:32  휴대전화   센터
# 160004  2018      평택시    평택소방서  팽성119안전센터  2018-02-17  07:23    기타   센터
#
#              출동년월일   출동시각  ... 외국인유무 환자증상1  환자증상2 질병외_교통사고  질병외_사고부상  \
# 160000  2018-02-17  17:02  ...     N  기타통증    NaN      NaN  기타(사고부상)
# 160001  2018-02-17  15:21  ...     N  기타통증     골절      NaN        낙상
# 160002  2018-02-18  09:23  ...     N    복통    NaN      NaN       NaN
# 160003  2018-02-16  21:34  ...     N    열상    NaN      NaN        열상
# 160004  2018-02-17  07:24  ...     Y    요통    NaN      NaN       NaN
#
#        질병외_비외상성손상      의식상태   구급대원1_자격 구급대원2_자격    운전요원_자격
# ...

# %%
data1.head()
# Out:
#     지역     1인/가구당     2인/가구당     3인/가구당     4인/가구당    5인/가구당    6인/가구당  \
# 0  가평군  33.271315  32.725287  17.541660  10.948876  3.971849  1.132503
# 1  고양시  22.856842  25.887038  24.452592  20.772585  4.746723  1.026187
# 2  과천시  18.240711  24.461934  25.784345  24.167470  5.867866  1.054717
# 3  광명시  22.068394  26.038126  24.238594  21.611465  4.851989  0.966811
# 4  광주시  22.625609  28.609487  23.278271  18.831774  5.124349  1.156471
#
#    7인 이상/가구당     지역별인구수   독거노인/노인     노인/전체  지역별구급인원  지역별호출건수  지역1인당호출건수  \
# 0   0.408510    63936.0  0.304307  0.232060      226     6489   0.101492
# 1   0.258033  1056853.0  0.230434  0.119979      625    41576   0.039339
# 2   0.422957    58325.0  0.194366  0.133288      150     3122   0.053528
# 3   0.224621   333114.0  0.231563  0.120085      218    12627   0.037906
# 4   0.374040   376819.0  0.215665  0.113946      306    15621   0.041455
#
#    관할인구(명)  구급1인당담당인구  구급1인당출동건수
# 0    62264        276  28.712389
# ...
