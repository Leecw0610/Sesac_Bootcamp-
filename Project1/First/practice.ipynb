# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('주문지역 기상 정보.csv')
# Out:
# C:\Users\jjanw\AppData\Local\Temp\ipykernel_15272\2790086969.py:1: DtypeWarning: Columns (8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('주문지역 기상 정보.csv')

# %%
data
# Out:
#               순번  시군구코드    광역시도명  시군구명      공개 일  공개 시간 강수 유형명  습도 1시간 강수량 값  \
# 0              1  42150      강원도   강릉시  20190101      0     없음  25         0
# 1              2  42820      강원도   고성군  20190101      0     없음  23         0
# 2              3  42170      강원도   동해시  20190101      0     없음  25         0
# 3              4  42230      강원도   삼척시  20190101      0     없음  23         0
# 4              5  42210      강원도   속초시  20190101      0     없음  20         0
# ...          ...    ...      ...   ...       ...    ...    ...  ..       ...
# 5626745  5626746  48870     경상남도   함양군  20210831   2000     없음  91       0.0
# 5626746  5626747  48880     경상남도   거창군  20210831   2000     없음  89       0.0
# 5626747  5626748  48890     경상남도   합천군  20210831   2000     없음  95       0.0
# 5626748  5626749  50110  제주특별자치도   제주시  20210831   2000     없음  79       0.0
# 5626749  5626750  50130  제주특별자치도  서귀포시  20210831   2000     없음  87       0.0
#
# ...

# %%
data['광역시도명'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
data.groupby(['광역시도명'])['습도'].median()
# Out:
# 광역시도명
# 강원도        71.0
# 경기도        69.0
# 경상남도       71.0
# 경상북도       71.0
# 광주광역시      75.0
# 대구광역시      60.0
# 대전광역시      70.0
# 부산광역시      64.0
# 서울특별시      62.0
# 세종특별자치시    74.0
# 울산광역시      70.0
# 인천광역시      67.0
# 전라남도       77.0
# 전라북도       76.0
# 제주특별자치도    72.0
# 충청남도       78.0
# 충청북도       74.0
# Name: 습도, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5626750 entries, 0 to 5626749
# Data columns (total 15 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   순번         int64
#  1   시군구코드      int64
#  2   광역시도명      object
#  3   시군구명       object
#  4   공개 일       int64
#  5   공개 시간      int64
#  6   강수 유형명     object
#  7   습도         int64
#  8   1시간 강수량 값  object
#  9   기온         object
#  10  풍속         object
#  11  바람강도 유형명   object
#  12  동쪽서쪽바람유형명  object
#  13  풍향값        int64
#  14  풍향카테고리명    object
# dtypes: int64(6), object(9)
# memory usage: 643.9+ MB

# %%
data1 = pd.read_csv('data/지역-업종 결제정보.csv')

# %%
data1
# Out:
#                   날짜  24시기준 해당시간 배달상점 업종명 배달상점 광역시도명 배달상점 시군구명  결제종류값
# 0         2019-07-31           0       피자        경기도  고양시 일산서구      3
# 1         2019-07-31           0   카페/디저트        경기도  고양시 일산동구      2
# 2         2019-07-31           0       치킨       전라남도       순천시      1
# 3         2019-07-31           0    족발/보쌈        경기도      의정부시      2
# 4         2019-07-31           0       치킨      서울특별시      영등포구      2
# ...              ...         ...      ...        ...       ...    ...
# 11023301  2020-07-31          23       야식    제주특별자치도      서귀포시      2
# 11023302  2020-07-31          23       치킨        경기도   안산시 상록구      2
# 11023303  2020-07-31          23       치킨        경기도      동두천시      1
# 11023304  2020-07-31          23       치킨        경기도      의정부시      2
# 11023305  2020-07-31          23       한식        경기도      의정부시      2
#
# [11023306 rows x 6 columns]

# %%
data2 = pd.read_csv('data/업종 목적지별 배달 주문건수.csv')

# %%
data2.head()
# Out:
#            날짜  시간대별 시간 배달상점 업종명 목적지 광역시도명 목적지 시군구명  주문 건수
# 0  2019-05-01        0    족발/보쌈      충청북도      제천시      2
# 1  2019-05-01        0       치킨      충청북도      제천시      5
# 2  2019-05-01        1       치킨      충청북도      제천시      6
# 3  2019-05-01       10    패스트푸드      충청북도      제천시      1
# 4  2019-05-01       10       한식      충청북도      제천시      4

# %%
data3 = pd.read_csv('data/업종-지역별 평균주문금액.csv')

# %%
data3.head()
# Out:
#            날짜  시간대별 시간 배달상점 업종명 배달상점 광역시도명 배달상점 시군구명  평균주문금액
# 0  2019-07-17        0      도시락        경기도      의정부시   21000
# 1  2019-07-17        0   돈까스/일식        경기도      의정부시   35000
# 2  2019-07-17        0   돈까스/일식       충청북도       제천시   42000
# 3  2019-07-17        0   배달전문업체        경기도  고양시 일산동구   23125
# 4  2019-07-17        0   배달전문업체        경기도      의정부시   16633

# %%
data4 = pd.read_csv('data/지역-업종 결제정보.csv')

# %%
data4.head()
# Out:
#            날짜  24시기준 해당시간 배달상점 업종명 배달상점 광역시도명 배달상점 시군구명  결제종류값
# 0  2019-07-31           0       피자        경기도  고양시 일산서구      3
# 1  2019-07-31           0   카페/디저트        경기도  고양시 일산동구      2
# 2  2019-07-31           0       치킨       전라남도       순천시      1
# 3  2019-07-31           0    족발/보쌈        경기도      의정부시      2
# 4  2019-07-31           0       치킨      서울특별시      영등포구      2

# %%
data5 = pd.read_csv('data/업종-거리구간 배달 건수.csv')

# %%
data5.head()
# Out:
#      년도  월 배달상점 업종명 배달상점 광역시도명 배달상점 시군구명         배달거리 구간명  배달주문수
# 0  2019  5       한식        경기도   수원시 장안구          1500m이하      6
# 1  2019  5       한식        경기도   수원시 장안구  1500m초과 3000m이하      7
# 2  2019  5       한식        경기도   수원시 장안구          5000m초과      1
# 3  2019  5    패스트푸드        경기도   수원시 팔달구          1500m이하      3
# 4  2019  5    패스트푸드        경기도   수원시 팔달구  3000m초과 5000m이하      3

# %%
data5
# Out:
#          년도   월 배달상점 업종명 배달상점 광역시도명 배달상점 시군구명         배달거리 구간명  배달주문수
# 0      2019   5       한식        경기도   수원시 장안구          1500m이하      6
# 1      2019   5       한식        경기도   수원시 장안구  1500m초과 3000m이하      7
# 2      2019   5       한식        경기도   수원시 장안구          5000m초과      1
# 3      2019   5    패스트푸드        경기도   수원시 팔달구          1500m이하      3
# 4      2019   5    패스트푸드        경기도   수원시 팔달구  3000m초과 5000m이하      3
# ...     ...  ..      ...        ...       ...              ...    ...
# 54749  2021  12        회    제주특별자치도      서귀포시  3000m초과 5000m이하      4
# 54750  2021  12        회    제주특별자치도      서귀포시          5000m초과      5
# 54751  2021  12        회       충청북도       제천시          1500m이하    105
# 54752  2021  12        회       충청북도       제천시  1500m초과 3000m이하     93
# 54753  2021  12        회       충청북도       제천시  3000m초과 5000m이하     35
#
# [54754 rows x 7 columns]
