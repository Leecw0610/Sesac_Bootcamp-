# %% [raw]
# ## IMDB 사이트에서 Top Box Office(US)에서
#
#  Movie , Title, content, score, 4개 영화에서 크롤링~

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#title찾기

# %%
url = 'https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht'

# %%
req = requests.get('https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht')

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb Top Box Office - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
# ...

# %%
title =soup.select('#boxoffice > table > tbody > tr > td > td >a')

# %%
title[0]
# Out:
# <a href="/title/tt6443346" title="Jaume Collet-Serra (dir.), Dwayne Johnson, Aldis Hodge">Black Adam</a>

# %%
title[0].text
# Out:
# 'Black Adam'

# %%
len(title)
# Out:
# 10

# %%
for i in range (len(title)) :
    temp=[]
    temp.append(title[i].text)

# %%
temp
# Out:
# ['Tár']

# %%
titled = titled.append(title[i].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 titled = titled.append(title[i].text)
#
# NameError: name 'titled' is not defined

# %% [raw]
# title2 = soup.findAll('td', {'class' : 'titleColumn'})

# %% [raw]
# title2

# %% [raw]
# title2[2].text

# %% [raw]
# list_m = ['Movie' , 'Title', 'content', 'score']

# %% [raw]
# for t in title2 :
#     temp =[]
#     for list_m in t.text :
#         temp.append(list_m.text)

# %%
url1 = 'https://www.imdb.com/title/tt6443346/reviews?ref_=tt_urv'

# %%
req = requests.get(url1)

# %%
review_title=soup.select('#reviews-container > li > div > div.review-container > div.review-header > div:nth-child(2)')

# %%
review_title

# %%
review_title_L =[]
for n in review_title :
    review_title_L.append(n.text)

# %%
review_title_L[0]

# %%
review_title_L[0].replace('\n', '')

# %%
data=[]
for i in range(10) :
    temp =[]
    temp.append(title[i].text)
    temp.append(review_title[i].text.replace('\n', ''))
    temp.append(review_score[i].text)
    temp.append(review_contents[i].text)
    data.append(temp)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 print(review_title[i])
#
# IndexError: list index out of range

# %%
review_score =soup.select('#reviews-container > li > div > div.review-container > div.review-header > div:nth-child(2) > div > div > span > span:nth-child(2)')

# %%
review_score

# %%
review_score_L =[]
for n in review_score :
    review_score_L.append(n.text)

# %%
review_score[0].text

# %%
review_contents = soup.select('#reviews-container > li > div > div.review-container > div.content > div.text')

# %%
review_contents[0].text

# %%
data=[]
for i in range(10) :
    temp =[]
    temp.append(title[i].text)
    temp.append(review_title[i].text.replace('\n', ''))
    temp.append(review_score[i].text)
    temp.append(review_contents[i].text)
    data.append(temp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       3 temp =[]
#       4 temp.append(title[i].text)
# ----> 5 temp.append(review_title[i].text.replace('\n', ''))
#       6 temp.append(review_score[i].text)
#       7 temp.append(review_contents[i].text)
#
# IndexError: list index out of range

# %%
data

# %%
df= pd.DataFrame(data)

# %%
df

# %%
df = pd.DataFrame(data, columns=['영화명','리뷰제목','리뷰평점','리뷰내용']
# Out:
#   Input In [23]
#     df = pd.DataFrame(data, columns=['영화명','리뷰제목','리뷰평점','리뷰내용']
#                                                                 ^
# SyntaxError: unexpected EOF while parsing
