# %% [markdown]
# ## 패키지 설치하기

# %%
#pip install emoji

# %%
import emoji as e

# %%
print(emoji.emojize('Hello world! :thumbs_up:'))

# %%
e.emojize(':thumbs_up:')

# %%
from emoji import emojize # 이방법은 추천하지 않음. 여러가지 셋을 import했을 떄 겹칠 수 있음.

# %%
#pip install pydataset

# %%
import pydataset as pds

# %%
data=pds.data()

# %%
data.head(1)
# Out:
#       dataset_id                                        title
# 0  AirPassengers  Monthly Airline Passenger Numbers 1949-1960

# %%
data[data['dataset_id'] =='mtcars']  #데이터 프레임 내에서 특정 변수값을 데이터프레임으로 도출
# Out:
#    dataset_id                       title
# 47     mtcars  Motor Trend Car Road Tests

# %%
df =pds.data('mtcars')

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df.shape # 행과 열 파악!
# Out:
# (32, 11)

# %%
df['am'].value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
df.gear.value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
df[(df['am'] == 0) & (df['gear']== 4)]
# Out:
#             mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4     2
# Merc 230   22.8    4  140.8   95  3.92  3.15  22.9   1   0     4     2
# Merc 280   19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4

# %%
df[(df['am'] == 0) & (df['gear']== 4)]
# Out:
#             mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4     2
# Merc 230   22.8    4  140.8   95  3.92  3.15  22.9   1   0     4     2
# Merc 280   19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4

# %%
len(df[(df['am'] == 0) & (df['gear']== 4)])
# Out:
# 4

# %%
df2 = pds.data('HairEyeColor')

# %%
df2
# Out:
#      Hair    Eye     Sex  Freq
# 1   Black  Brown    Male    32
# 2   Brown  Brown    Male    53
# 3     Red  Brown    Male    10
# 4   Blond  Brown    Male     3
# 5   Black   Blue    Male    11
# 6   Brown   Blue    Male    50
# 7     Red   Blue    Male    10
# 8   Blond   Blue    Male    30
# 9   Black  Hazel    Male    10
# 10  Brown  Hazel    Male    25
# 11    Red  Hazel    Male     7
# 12  Blond  Hazel    Male     5
# 13  Black  Green    Male     3
# 14  Brown  Green    Male    15
# 15    Red  Green    Male     7
# 16  Blond  Green    Male     8
# 17  Black  Brown  Female    36
# 18  Brown  Brown  Female    66
# 19    Red  Brown  Female    16
# 20  Blond  Brown  Female     4
# 21  Black   Blue  Female     9
# 22  Brown   Blue  Female    34
# 23    Red   Blue  Female     7
# 24  Blond   Blue  Female    64
# 25  Black  Hazel  Female     5
# 26  Brown  Hazel  Female    29
# 27    Red  Hazel  Female     7
# 28  Blond  Hazel  Female     5
# 29  Black  Green  Female     2
# ...

# %%
data = pds.data()

# %%
df3 = pds.data('cake')

# %%
df3
# Out:
#      replicate recipe  temperature  angle  temp
# 1            1      A          175     42   175
# 2            1      A          185     46   185
# 3            1      A          195     47   195
# 4            1      A          205     39   205
# 5            1      A          215     53   215
# ..         ...    ...          ...    ...   ...
# 266         15      C          185     28   185
# 267         15      C          195     25   195
# 268         15      C          205     25   205
# 269         15      C          215     31   215
# 270         15      C          225     25   225
#
# [270 rows x 5 columns]

# %% [raw]
# 'cake'내에서 recipe이 C에 해당하는 데이터들의 temp 평균을 구하시오.

# %%
df5 =pds.data('volcano')

# %%
df5
# Out:
#      V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  ...  V52  V53  V54  V55  \
# 1   100  100  101  101  101  101  101  100  100  100  ...  107  107  107  106
# 2   101  101  102  102  102  102  102  101  101  101  ...  108  108  107  107
# 3   102  102  103  103  103  103  103  102  102  102  ...  109  108  108  107
# 4   103  103  104  104  104  104  104  103  103  103  ...  109  109  108  108
# 5   104  104  105  105  105  105  105  104  104  103  ...  110  109  109  108
# 6   105  105  105  106  106  106  106  105  105  104  ...  110  110  109  108
# 7   105  106  106  107  107  107  107  106  106  105  ...  110  111  110  109
# 8   106  107  107  108  108  108  108  107  107  106  ...  113  112  110  110
# 9   107  108  108  109  109  109  109  108  108  107  ...  115  114  112  110
# 10  108  109  109  110  110  110  110  109  109  108  ...  117  115  113  111
# 11  109  110  110  111  111  111  111  110  110  110  ...  118  116  114  112
# ...

# %%
data.iloc[151]['dataset_id']
# Out:
# 'airmay'

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %% [raw]
# 헤어는 검정, 눈 브라운 , 남성

# %%
df2
# Out:
#      Hair    Eye     Sex  Freq
# 1   Black  Brown    Male    32
# 2   Brown  Brown    Male    53
# 3     Red  Brown    Male    10
# 4   Blond  Brown    Male     3
# 5   Black   Blue    Male    11
# 6   Brown   Blue    Male    50
# 7     Red   Blue    Male    10
# 8   Blond   Blue    Male    30
# 9   Black  Hazel    Male    10
# 10  Brown  Hazel    Male    25
# 11    Red  Hazel    Male     7
# 12  Blond  Hazel    Male     5
# 13  Black  Green    Male     3
# 14  Brown  Green    Male    15
# 15    Red  Green    Male     7
# 16  Blond  Green    Male     8
# 17  Black  Brown  Female    36
# 18  Brown  Brown  Female    66
# 19    Red  Brown  Female    16
# 20  Blond  Brown  Female     4
# 21  Black   Blue  Female     9
# 22  Brown   Blue  Female    34
# 23    Red   Blue  Female     7
# 24  Blond   Blue  Female    64
# 25  Black  Hazel  Female     5
# 26  Brown  Hazel  Female    29
# 27    Red  Hazel  Female     7
# 28  Blond  Hazel  Female     5
# 29  Black  Green  Female     2
# ...

# %%
df2[(df2['Hair'] == 'Black') & (df2['Eye'] == 'Brown') & (df2['Sex'] =='Male')]
# Out:
#     Hair    Eye   Sex  Freq
# 1  Black  Brown  Male    32

# %%
len(df2[(df2['Hair'] == 'Black') & (df2['Eye'] == 'Brown') & (df2['Sex'] =='Male')])
# Out:
# 1

# %%
df2.groupby(['Hair','Eye','Sex']).count()
# Out:
#                     Freq
# Hair  Eye   Sex
# Black Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Blond Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Brown Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Red   Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1

# %%
import pandas as pd

# %%
df = pd.DataFrame({'name' : ['김지훈','이유진','박동현','김민지'],
                 'english': [90, 80, 60, 70],
                 'math' : [50, 60, 100, 20]})

# %%
df['english'].mean()
# Out:
# 75.0

# %%
df['english'].sum()
# Out:
# 300

# %%
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df =df.rename({'name':'이름'}, axis=1)

# %%
df
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df2 = df

# %%
df2
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df.rename({'이름':'name'}, axis =1)
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df2
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df3 = df.copy()

# %%
df3
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df['name'] = '예진'

# %%
df
# Out:
#     이름  english  math name
# 0  김지훈       90    50   예진
# 1  이유진       80    60   예진
# 2  박동현       60   100   예진
# 3  김민지       70    20   예진

# %%
df3
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
id (df) #원본
# Out:
# 1632814381712

# %%
id (df2) #그냥 변수명 복사, 얕은 복사 (shallow copy)
# Out:
# 1632814381712

# %%
id (df3) #깊은 복사 (deep copy), 원본을 변화시키고 싶지 않을 때 씀. 데이터가 너무 클 시에는 쓸 수 없음
# Out:
# 1632814382624

# %%
df = pd.DataFrame({'var1':[4,3,8],
                  'var2':[2,6,1]})

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df ['var_sum']= df['var1']+df['var2'] # 2개의 데이터를 합쳐 새로운 데이터를 출력!

# %%
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean']= (df['var1']+df['var2']) /2

# %%
df['var_mean']
# Out:
# 0    3.0
# 1    4.5
# 2    4.5
# Name: var_mean, dtype: float64

# %%
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
import pydataset as pds

# %%
mpg = pds.data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#mpg= pds.data('mpg',show_doc=True)

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  total
# 1    compact   23.5
# 2    compact   25.0
# 3    compact   25.5
# ...

# %%
mpg['total'].mean()

# %%
len(mpg[mpg['total'] > 20])

# %%
# 20 >  ; pass
# 20 <= ; fail

# %%
def isPass(t) : #t는 total을 의미.
    if t >20 :
        return 'Pass'
    else :
        return 'Fail'

# %%
mpg['test'] = mpg['total'].apply(isPass) #apply는 어떤 함수의 기능을 시리즈에 사용하고 싶을 때 사용.

# %%
mpg['test'].value_counts()

# %%
mpg['test']

# %%
mpg

# %%
mpg['grade'] = 
# mpg['total'] >= 30 'A'
# mpg['total'] >= 20 'B'
# else 'C'

# %%
mpg['total']

# %%
def grade_(t) :
    if t >= 30 :
        return 'A'
    elif t >= 20 :
        return 'B'
    else :
        return 'C'

# %%
mpg['grade'] = mpg['total'].apply(grade_)

# %%
mpg['grade']

# %%
mpg['grade'].value_counts().sort_index() #index값을 알파벳 순으로 정렬!

# %% [raw]
# -----------함수선언으로 구하는 것이  첫번쨰 방법----------

# %%
import numpy as np

# %%
mpg['test2'] = np.where(mpg['total'] >20, 'Pass', 'Fail')

# %%
mpg['test2'].value_counts()

# %%
np.where(mpg['total'] >30, 'A',
np.where(mpg['total'] >20, 'B', 'Fail'))

# %%
mpg['grade2'] = np.where(mpg['total'] >=30, 'A',
                np.where(mpg['total'] >=20, 'B', 'C'))

# %%
mpg['grade2']

# %%
mpg['grade2'].value_counts()

# %%
mpg['grade2'].value_counts().sort_index()

# %%
type(np.where(mpg['total'] >30, 'A',
np.where(mpg['total'] >20, 'B', 'Fail')))

# %%
mpg['class'].unique()

# %%
mpg['class']

# %%
# class -> compact, subcompact, 2seater -> small ////// large

# %%
def size_(t) :
    c= ['compact', 'subcompact', '2seater']
    if t in c :
        return 'small'
    else :
        return 'large'

# %%
mpg['size'] = mpg['class'].apply(size_)

# %%
mpg['size']

# %%
mpg['size'].value_counts()

# %%
mpg['size2']=np.where(mpg['class'] =='compact' ,  'small',
             np.where(mpg['class'] =='subcompact', 'small',
             np.where(mpg['class'] =='2seater', 'small', 'large')))

# %%
mpg['size2']

# %%
mpg['size2'].value_counts()

# %%
###풀이

# %%
def isSize(c) :
    l = ['compact' , 'subcompact' , '2seater']
    if c in l :
        return 'small'
    return 'large'

# %%
isSize('a')

# %%
mpg['size']=mpg['class'].apply(isSize)

# %%
mpg['size'].value_counts()

# %%
np.where((mpg['class']== 'compact') |
         (mpg['class']== 'subcompact') |
         (mpg['class']== '2seater'), 'small', 'large')

# %%
np.where(mpg['class'].isin(['compact' , 'subcompact' , '2seater']), 'small', 'large')

# %%
mpg['size2']=np.where(mpg['class'].isin(['compact' , 'subcompact' , '2seater']), 'small', 'large')

# %%
mpg['size2']

# %%
mpg['size2'].value_counts()

# %% [markdown]
# #### 교재 p.130 분석 도전

# %%
#1번

# %%
import pandas as pd

# %%
data = pd.read_csv('221026/midwest.csv')

# %%
midwest=data

# %%
data.info()

# %%
data.head()

# %%
data.shape

# %%
data= data.rename({'poptotal': 'total'}, axis =1)

# %%
data = data.rename({'popasian': 'asian'}, axis =1 )

# %%
data

# %%
asia_P = data['asian'] / data['total'] * 100

# %%
asia_P

# %%
data = pd.concat([data, asia_P], axis=1)

# %%
data = data.rename({'0':'asia_P'}, axis=1)

# %%
data

# %%
data['asian'] / data['total'] * 100

# %%
asia_M = data['asian'].sum() / data['total'].sum()

# %%
asia_M

# %%
asia_P.mean()

# %%
### 풀이

# %% [raw]
# 1번의 세가지방법

# %%
midwest.rename({'poptotal':'total', 'popasian':'asian'}, axis=1)

# %%
midwest.rename({'poptotal':'total', 'popasian':'asian'}, axis=1, inplace = True)

# %%
midwest.rename(columns = {'poptotal':'total', 'popasian':'asian'})

# %%
#2번부터

# %%
midwest['percent']= midwest['asian'] / midwest['total'] * 100

# %%
midwest['percent']

# %%
midwest['percent'].mean()

# %%
midwest['size'] =np.where(midwest['percent'] > midwest['percent'].mean(), 'large', 'small')

# %%
midwest['size'].value_counts()

# %%
midwest

# %%
def isSize(percent, mean) :
    if percent > mean :
        return 'large'
    return 'small'

# %%
midwest['size2'] = \
midwest['percent'].apply(isSize, args=[midwest['percent'].mean()])

# %%
midwest['size2']

# %%
midwest['size2'].value_counts()

# %% [markdown]
# ##### 교재 p.176 분석 도전

# %%
#Q1

data

# %%
import pandas as pd

# %%
data = pd.read_csv('221026/midwest.csv')

# %%
midwest = data

# %%
no_adults_p = (midwest['poptotal'] - midwest['popadults']) / midwest['poptotal'] * 100

# %%
no_adults_p
# Out:
# 0      34.486307
# 1      36.721250
# 2      35.501301
# 3      37.440758
# 4      31.819740
#          ...
# 432    35.731093
# 433    34.693302
# 434    31.307712
# 435    36.602052
# 436    36.422797
# Length: 437, dtype: float64

# %%
data['no_adults_p'] = no_adults_p

# %%
data
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
no_adults_p[0:437]
# Out:
# 0      34.486307
# 1      36.721250
# 2      35.501301
# 3      37.440758
# 4      31.819740
#          ...
# 432    35.731093
# 433    34.693302
# 434    31.307712
# 435    36.602052
# 436    36.422797
# Length: 437, dtype: float64

# %%
no_adults_p.max()
# Out:
# 51.50117164616286

# %%
no_adults_p.value_counts()
# Out:
# 34.486307    1
# 36.325806    1
# 36.914393    1
# 34.732153    1
# 37.547252    1
#             ..
# 37.421830    1
# 36.849668    1
# 36.651341    1
# 35.649870    1
# 36.422797    1
# Length: 437, dtype: int64

# %%
no_adults_p.sort_values
# Out:
# <bound method Series.sort_values of 0      34.486307
# 1      36.721250
# 2      35.501301
# 3      37.440758
# 4      31.819740
#          ...
# 432    35.731093
# 433    34.693302
# 434    31.307712
# 435    36.602052
# 436    36.422797
# Length: 437, dtype: float64>

# %%
no_adults_p.sort_values(ascending = False).head(5)
# Out:
# 230    51.501172
# 404    50.591260
# 281    49.320727
# 247    49.059183
# 154    47.358182
# dtype: float64

# %%
import numpy as np

# %%
np_grade = np.where(data['no_adults_p'] >= 40, 'L',
             np.where(data['no_adults_p'] >= 30, 'M', 'S'))


#np.where((mpg['class']== 'compact') |
#         (mpg['class']== 'subcompact') |
#         (mpg['class']== '2seater'), 'small', 'large')
         
         
       # mpg['size2']=np.where(mpg['class'] =='compact' ,  'small',
          #  np.where(mpg['class'] =='subcompact', 'small',
             #np.where(mpg['class'] =='2seater', 'small', 'large')))

# %%
np_grade
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'L', 'M', 'M', 'M',
#        'M', 'L', 'M', 'M', 'M', 'L', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'L',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'L', 'M', 'L', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'L', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'L', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'L', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'L', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
# ...

# %%
###풀이

# %%
#전체인구 - 성인인구

# %%
N_a_p = (midwest['poptotal'] - midwest['popadults']) / midwest['poptotal'] * 100

# %%
N_a_p
# Out:
# 0      34.486307
# 1      36.721250
# 2      35.501301
# 3      37.440758
# 4      31.819740
#          ...
# 432    35.731093
# 433    34.693302
# 434    31.307712
# 435    36.602052
# 436    36.422797
# Length: 437, dtype: float64

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest.sort_values('no_adults_p')
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 235  1238   KEWEENAW    MI  0.020      1701    85.050000      1688         1
# 265  1268  ROSCOMMON    MI  0.034     19776   581.647059     19597        37
# 229  1232       IRON    MI  0.070     13175   188.214286     13028         4
# 194  1197     ALCONA    MI  0.041     10145   247.439024     10026        27
# 365  2981      ADAMS    WI  0.041     15682   382.487805     15001       375
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 154   715     MONROE    IN  0.024    108978  4540.750000    102752      2835
# 247  1250    MECOSTA    MI  0.034     37308  1097.294120     35739       978
# 281  2013     ATHENS    OH  0.030     59549  1984.966670     56163      1678
# 404  3020  MENOMINEE    WI  0.021      3890   185.238095       416         0
# 230  1233   ISABELLA    MI  0.034     54624  1606.588240     52212       635
#
# ...

# %%
midwest.sort_values('no_adults_p',ascending = False)[['county','no_adults_p']][:5]
# Out:
#         county  no_adults_p
# 230   ISABELLA    51.501172
# 404  MENOMINEE    50.591260
# 281     ATHENS    49.320727
# 247    MECOSTA    49.059183
# 154     MONROE    47.358182

# %%
midwest['grade']=np.where(midwest['no_adults_p'] >= 40, 'large',
         np.where(midwest['no_adults_p'] >= 30, 'middle', 'small'))

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest['grade'].value_counts()
# Out:
# middle    396
# large      32
# small       9
# Name: grade, dtype: int64

# %%
midwest['Aratio'] = midwest['popasian']/ midwest['poptotal'] * 100

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest.sort_values('Aratio')
# Out:
#       PID      county state   area  poptotal    popdensity  popwhite  \
# 404  3020   MENOMINEE    WI  0.021      3890    185.238095       416
# 105   666      BENTON    IN  0.024      9441    393.375000      9389
# 109   670     CARROLL    IN  0.022     18809    854.954545     18720
# 358  2090      VINTON    OH  0.024     11098    462.416667     11071
# 390  3006        IRON    WI  0.047      6153    130.914894      6121
# ..    ...         ...   ...    ...       ...           ...       ...
# 180   741  TIPPECANOE    IN  0.030    130598   4353.266670    122013
# 15    576        COOK    IL  0.058   5105067  88018.396600   3204947
# 274  1277   WASHTENAW    MI  0.041    282937   6900.902440    236390
# 9     570   CHAMPAIGN    IL  0.058    173025   2983.189660    146506
# 21    582     DU PAGE    IL  0.020    781666  39083.300000    714905
#
#      popblack  popamerindian  popasian  ...  percpovertyknown  \
# 404         0           3469         0  ...         98.200514
# ...

# %%
midwest.sort_values('Aratio')[['state', 'county', 'Aratio']][:10]
# Out:
#     state     county    Aratio
# 404    WI  MENOMINEE  0.000000
# 105    IN     BENTON  0.010592
# 109    IN    CARROLL  0.015950
# 358    OH     VINTON  0.027032
# 390    WI       IRON  0.032504
# 85     IL      SCOTT  0.053154
# 112    IN       CLAY  0.060716
# 261    MI     OSCODA  0.063759
# 340    OH      PERRY  0.066546
# 73     IL      PIATT  0.070749

# %% [raw]
# State 별로 Aratio 합이 작은 순서부터 구하기

# %%
len(midwest['state'].unique())
# Out:
# 5

# %%
midwest.groupby('state')['Aratio'].mean().sort_values() #가장 낮은 평균값부터 보기
# Out:
# state
# IN    0.382658
# OH    0.432803
# MI    0.506877
# WI    0.556213
# IL    0.563895
# Name: Aratio, dtype: float64

# %%
len(midwest['county'].unique())
# Out:
# 320

# %%
len(midwest)
# Out:
# 437

# %%
midwest['inmetro'].value_counts()
# Out:
# 0    287
# 1    150
# Name: inmetro, dtype: int64

# %%
midwest.loc[0, 'county'] = 'Hojin'  #[바꾸고 싶은 인덱스값, 바꿔야 하는 칼럼값]

# %% [markdown]
# ## midwest.apply
# ## np.where
# ## unique
# ## value_counts
# ## sort_values
#
# 매우 중요!!!!
