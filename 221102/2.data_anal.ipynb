# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=202210')

# %%
soup = BeautifulSoup(req.text, 'xml')

# %%
soup.items()[0]

# %%
col_names = []
for item in soup.items()[0] :
    #print(item.name)
    
    #print('--')
    col_names.append(item.name)

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text.strip())
        #print(t.text)
        #print('------')  
    data.append(temp)

# %%
df = pd.DataFrame(data, columns = col_names)

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=(ym)')

# %%
ym = df['년'] + df['월'].str.zfill(2)

# %%
df

# %%
import numpy as np

# %%
df = df.dropna(axis= 1)

# %%
df['계약일'] = df['년'] + df['월'].str.zfill(2)+ df['일'].str.zfill(2)

# %%
df

# %%
df_10 = df

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=202209')

# %%
soup = BeautifulSoup(req.text, 'xml')

# %%
soup.items()[0]

# %%
col_names = []
for item in soup.items()[0] :
    #print(item.name)
    
    #print('--')
    col_names.append(item.name)

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text.strip())
        #print(t.text)
        #print('------')  
    data.append(temp)

# %%
data

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=(ym)')

# %%
ym = df['년'] + df['월'].str.zfill(2)

# %%
df = pd.DataFrame(data, columns = col_names)

# %%
df = df.dropna(axis= 1)

# %%
df['계약일'] = df['년'] + df['월'].str.zfill(2)+ df['일'].str.zfill(2)

# %%
df

# %%
df9 = df

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=(ym)')

# %% [raw]
# ym = 년 + 월
#
# df['계약일'] = df['년'] + df['월'].str.zfill(2)+ df['일'].str.zfill(2)
#
# ym = df['년'] + df['월'].str.zfill(2)

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=(ym)')

# %%
ym = df['년'] + df['월'].str.zfill(2)

# %%
for y in range(2022, 2023) :
    for m in range(6, 11) :
        url ='DEAL_YMD = ' + str(y) + str(m).zfill(2)
        req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=url')
        
        col_names = []
        for item in soup.items()[0] :
            col_names.append(item.name)
            
        data = []
        for item in soup.items :
            temp = []
            
            for t in item :
                temp.append(t.text.strip())
            data.append(temp)
            df = pd.DataFrame(data, columns = col_names)

# %%
df

# %%
#해답

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=202206')

# %%
data=[]
col_names=[]

for m in range (6, 11) :
    url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent'
    serviceKey = 'BAc5c%2B7CgdSM2dp9F0gq%2FN7FR4TwTghq%2BzHtk7BmmX%2B588SuKYRFAW77xC6eaS6kpEZgWxZnz9a1TSk%2FO%2F6gUg%3D%3D'
    lawd_cd = '11530' #지역
    deal_ymd = '2022' + str(m).zfill(2) #계약일
    
    api_url = url + '?' + 'servicekey=' + serviceKey +'&LAWD_CD='+ lawd_cd + '&DEAL_YMD=' +deal_ymd
    
    print(api_url)
# Out:
# http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?servicekey=BAc5c%2B7CgdSM2dp9F0gq%2FN7FR4TwTghq%2BzHtk7BmmX%2B588SuKYRFAW77xC6eaS6kpEZgWxZnz9a1TSk%2FO%2F6gUg%3D%3D&LAWD_CD=11530&DEAL_YMD=202206
# http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?servicekey=BAc5c%2B7CgdSM2dp9F0gq%2FN7FR4TwTghq%2BzHtk7BmmX%2B588SuKYRFAW77xC6eaS6kpEZgWxZnz9a1TSk%2FO%2F6gUg%3D%3D&LAWD_CD=11530&DEAL_YMD=202207
# http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?servicekey=BAc5c%2B7CgdSM2dp9F0gq%2FN7FR4TwTghq%2BzHtk7BmmX%2B588SuKYRFAW77xC6eaS6kpEZgWxZnz9a1TSk%2FO%2F6gUg%3D%3D&LAWD_CD=11530&DEAL_YMD=202208
# ...

# %%
req = requests.get(api_url)
soup = BeautifulSoup(req.text,'xml')

if not col_names :
    for item in soup.items()[0]:
        col_names.append(item.name)
        
    for item in soup.items :
        temp =[]
        for t in item:
            temp.append(t.text.strip())
        data.append(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 req = requests.get(api_url)
#       2 soup = BeautifulSoup(req.text,'xml')
#       4 if not col_names :
#
# NameError: name 'requests' is not defined

# %%
soup.items()

# %%
df = pd.DataFrame(data, columns = col_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df = pd.DataFrame(data, columns = col_names)
#
# NameError: name 'pd' is not defined

# %%
df

# %%
from tqdm import tqdm

# %%
data = []
col_names=[]
for m in tqdm(range(1, 13)):
    url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent'
    serviceKey = 'BAc5c%2B7CgdSM2dp9F0gq%2FN7FR4TwTghq%2BzHtk7BmmX%2B588SuKYRFAW77xC6eaS6kpEZgWxZnz9a1TSk%2FO%2F6gUg%3D%3D'
    lawd_cd = '11530' #지역
    deal_ymd = '2022' + str(m).zfill(2) #계약일
    api_url = url + '?' + 'serviceKey=' + serviceKey + '&LAWD_CD=' \
    + lawd_cd + '&DEAL_YMD=' + deal_ymd
    req = requests.get(api_url)
    soup = BeautifulSoup(req.text,'xml')
    if not col_names :
        for item in soup.items()[0]:
            col_names.append(item.name)
    for item in soup.items :
        temp = []
        for t in item :
            temp.append(t.text.strip())
        data.append(temp)

df = pd.DataFrame(data, columns=col_names)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:07<00:00,  1.55it/s]

# %%
df.shape
# Out:
# (8310, 17)

# %%
df=df.replace('', np.nan)

# %%
df.isnull().sum()
# Out:
# 갱신요구권사용    7044
# 건축년도          0
# 계약구분       2729
# 계약기간       3250
# 년             0
# 법정동           0
# 보증금액          0
# 아파트           0
# 월             0
# 월세금액          0
# 일             0
# 전용면적          0
# 종전계약보증금    2729
# 종전계약월세     2729
# 지번            0
# 지역코드          0
# 층             0
# dtype: int64

# %%
df[df['아파트']=='디큐브시티']
# Out:
#      갱신요구권사용  건축년도 계약구분         계약기간     년   법정동     보증금액    아파트   월 월세금액   일  \
# 0        NaN  2011   신규  22.03~24.03  2022  신도림동  115,000  디큐브시티   1    0   3
# 38       NaN  2011   갱신  22.01~24.01  2022  신도림동   95,000  디큐브시티   1    0  14
# 39       NaN  2011  NaN          NaN  2022  신도림동   50,000  디큐브시티   1  125  14
# 79       NaN  2011   신규  22.02~23.02  2022  신도림동    5,000  디큐브시티   1  350  25
# 82        사용  2011   갱신  22.02~24.02  2022  신도림동   73,000  디큐브시티   1   37  26
# 658       사용  2011   갱신  22.02~24.02  2022  신도림동   72,000  디큐브시티   2    0   5
# 673      NaN  2011  NaN          NaN  2022  신도림동   48,000  디큐브시티   2   12   8
# 712      NaN  2011   신규  22.03~24.03  2022  신도림동    5,000  디큐브시티   2  255  15
# 713      NaN  2011   신규  22.03~23.03  2022  신도림동    5,000  디큐브시티   2  260  15
# 725       사용  2011   갱신  22.03~24.03  2022  신도림동   42,000  디큐브시티   2  168  17
# 791       사용  2011   갱신  22.03~24.03  2022  신도림동    3,000  디큐브시티   2  294  28
# ...

# %%
df['아파트'].value_counts()
# Out:
# 센트레빌레우스1단지        1337
# 오류동행복주택            219
# 천왕이펜하우스7단지         212
# 천왕연지타운2단지          209
# 현대                 204
#                   ...
# (791-18)             1
# (793-6)              1
# (771-30)             1
# (717-15)경원주택5동       1
# (792-6)              1
# Name: 아파트, Length: 455, dtype: int64

# %%
df_sen= df[df['아파트'] ==  '센트레빌레우스1단지']

# %% [markdown]
# ## 월별 월세 / 전세 변화량 (전용면적 고려)
# ## 월세의 경우 보증금액 변화도 고려

# %%
df.columns
# Out:
# Index(['갱신요구권사용', '건축년도', '계약구분', '계약기간', '년', '법정동', '보증금액', '아파트', '월',
#        '월세금액', '일', '전용면적', '종전계약보증금', '종전계약월세', '지번', '지역코드', '층'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8244 entries, 0 to 8243
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   갱신요구권사용  1266 non-null   object
#  1   건축년도     8244 non-null   object
#  2   계약구분     5582 non-null   object
#  3   계약기간     5061 non-null   object
#  4   년        8244 non-null   object
#  5   법정동      8244 non-null   object
#  6   보증금액     8244 non-null   object
#  7   아파트      8244 non-null   object
#  8   월        8244 non-null   object
#  9   월세금액     8244 non-null   object
#  10  일        8244 non-null   object
#  11  전용면적     8244 non-null   object
#  12  종전계약보증금  5582 non-null   object
#  13  종전계약월세   5582 non-null   object
#  14  지번       8244 non-null   object
#  15  지역코드     8244 non-null   object
#  16  층        8244 non-null   object
# dtypes: object(17)
# memory usage: 1.1+ MB

# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore') #warning 안뜨게 하기

# %% [raw]
# 1)  월별 전용면적 보증금액  [월세]
# 2)  월별 전용면적     [전세]

# %%
df1=df.groupby(['월','전용면적'])['월세금액'].mean() #df1은 월세변화량

# %%
df1
# Out:
# 월  전용면적
# 1  101.48      0.000000e+00
#    101.9806    5.000000e+01
#    102.6       4.000000e+01
#    105.45      1.751850e+04
#    110.188     0.000000e+00
#                    ...
# 9  84.9852     0.000000e+00
#    84.99       6.762501e+27
#    84.994      0.000000e+00
#    96.3        1.300000e+02
#    96.41       2.400000e+01
# Name: 월세금액, Length: 2462, dtype: float64

# %% [raw]
# df2 = df.groupby(['월','전용면적'])['']

# %%
df1.describe()
# Out:
# count    2462.000000
# mean             inf
# std              NaN
# min         0.000000
# 25%         0.000000
# 50%        17.500000
# 75%       445.833333
# max              inf
# Name: 월세금액, dtype: float64

# %%
df2=df.groupby(['월','전용면적'])['월세금액'].mean().reset_index().sort_values('월세금액',ascending=False)

# %%
import seaborn as sns

# %%
sns.barplot(data = df2, x= df['월'], y = df['월세금액'].mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10384\830131560.py in <module>
# ----> 1 sns.barplot(data = df2, x= df['월'], y = df['월세금액'].mean())
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
df_sen=df[df['아파트']=='센트레빌레우스1단지']

# %%
df_sen['월세금액'] = df_sen['월세금액'].astype(int)

# %%
df_sen[df_sen['월세금액'] == df_sen['월세금액'].max()]
# Out:
#      갱신요구권사용  건축년도 계약구분 계약기간     년  법정동    보증금액         아파트  월  월세금액  일  \
# 5758     NaN  2020  NaN  NaN  2022  개봉동  27,891  센트레빌레우스1단지  7   432  1
#
#          전용면적 종전계약보증금 종전계약월세   지번   지역코드  층
# 5758  84.9716     NaN    NaN  497  11530  6

# %%
df_sen
# Out:
#      갱신요구권사용  건축년도 계약구분         계약기간     년  법정동    보증금액         아파트   월  월세금액  \
# 444      NaN  2020   신규  22.03~24.03  2022  개봉동  25,000  센트레빌레우스1단지   1    37
# 462      NaN  2020  NaN          NaN  2022  개봉동  27,000  센트레빌레우스1단지   1    44
# 484      NaN  2020  NaN          NaN  2022  개봉동  22,000  센트레빌레우스1단지   1    45
# 1153     NaN  2020  NaN          NaN  2022  개봉동  25,000  센트레빌레우스1단지   2    39
# 1181     NaN  2020  NaN          NaN  2022  개봉동  17,000  센트레빌레우스1단지   2     0
# ...      ...   ...  ...          ...   ...  ...     ...         ...  ..   ...
# 8200     NaN  2020  NaN          NaN  2022  개봉동  20,660  센트레빌레우스1단지  10    43
# 8299     NaN  2020  NaN          NaN  2022  개봉동  27,891  센트레빌레우스1단지  11    45
# 8300     NaN  2020  NaN          NaN  2022  개봉동  20,660  센트레빌레우스1단지  11    43
# 8303     NaN  2020  NaN          NaN  2022  개봉동  25,825  센트레빌레우스1단지  11    40
# 8305     NaN  2020  NaN          NaN  2022  개봉동  20,660  센트레빌레우스1단지  11    43
#
# ...

# %%
df_sen_group = df_sen.groupby('월','전용면적')['월세금액']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: '전용면적'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df_sen_group = df_sen.groupby('월','전용면적')['월세금액']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7707, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7705 if level is None and by is None:
#    7706     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7707 axis = self._get_axis_number(axis)
# ...

# %% [raw]
# 그래프의 x 에 월 y에 금액 hue 전세,월세

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(60,10))
sns.pointplot(x = '원',y='보증금액', hue='신용면적', data=df_sen_group)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10384\2033647359.py in <module>
#       1 plt.figure(figsize =(60,10))
# ----> 2 sns.pointplot(x = '원',y='보증금액', hue='신용면적', data=df_sen_group)
#
# NameError: name 'df_sen_group' is not defined
