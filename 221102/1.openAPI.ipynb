# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=202210')

# %%
soup = BeautifulSoup(req.text, 'xml')

# %%
soup.select('법정동')
# Out:
# [<법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
# ...

# %%
# 구로동(11530) // 2022.10월
# 건축년도 / 연월일 / 법정동 / 보증금액 / 아파트 / 월세금액 / 전용면적 / 층

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&LAWD_CD=11530&DEAL_YMD=202210')

# %%
year=soup.select('건축년도')

# %%
year
# Out:
# [<건축년도>2000</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2011</건축년도>,
#  <건축년도>2004</건축년도>,
#  <건축년도>1996</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1987</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2018</건축년도>,
#  <건축년도>1994</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1989</건축년도>,
#  <건축년도>2006</건축년도>,
#  <건축년도>2000</건축년도>,
#  <건축년도>2015</건축년도>,
#  <건축년도>2015</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2011</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>1987</건축년도>,
#  <건축년도>1994</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1989</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2004</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2000</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1997</건축년도>,
#  <건축년도>2006</건축년도>,
#  <건축년도>2004</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1993</건축년도>,
#  <건축년도>2001</건축년도>,
# ...

# %%
#각 항목의 값 뽑아내기

year_L = []
for n in year :
    year_L.append(n.text)

# %%
year_L
# Out:
# ['2000',
#  '2001',
#  '2011',
#  '2004',
#  '1996',
#  '1999',
#  '1987',
#  '1999',
#  '2018',
#  '1994',
#  '1999',
#  '2001',
#  '1999',
#  '2003',
#  '2003',
#  '1999',
#  '1989',
#  '2006',
#  '2000',
#  '2015',
#  '2015',
#  '2001',
#  '2001',
#  '2011',
#  '2001',
#  '1987',
#  '1994',
#  '2003',
#  '1999',
#  '1999',
#  '1989',
#  '1999',
#  '2001',
#  '2004',
#  '2003',
#  '1999',
#  '1999',
#  '2000',
#  '1999',
#  '1997',
#  '2006',
#  '2004',
#  '1999',
#  '1993',
#  '2001',
#  '2021',
#  '2000',
#  '2001',
#  '2000',
#  '2003',
#  '1999',
#  '2000',
#  '1994',
#  '2003',
#  '1994',
#  '2000',
#  '2004',
#  '1998',
#  '1995',
#  '1998',
#  '1986',
#  '2000',
#  '2006',
#  '2004',
#  '1989',
#  '2007',
#  '2007',
#  '1988',
#  '1987',
#  '2006',
#  '2009',
#  '1987',
#  '2000',
#  '1986',
#  '1984',
#  '2007',
#  '1995',
#  '2003',
#  '1984',
#  '1989',
#  '1997',
#  '1986',
#  '2000',
#  '2000',
#  '1985',
#  '1987',
#  '1988',
#  '1996',
#  '2000',
#  '1992',
# ...

# %%
ymd_y = soup.select('년')

# %%
ymd_y
# Out:
# [<년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
#  <년>2022</년>,
# ...

# %%
ymd_y_L = []
for n in ymd_y :
    ymd_y_L.append(n.text)

# %%
ymd_y_L
# Out:
# ['2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
# ...

# %%
ymd_m = soup.select('월')

# %%
ymd_m
# Out:
# [<월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
#  <월>10</월>,
# ...

# %%
ymd_m_L = []
for n in ymd_m :
    ymd_m_L.append(n.text)

# %%
ymd_d = soup.select('일')

# %%
ymd_d
# Out:
# [<일>2</일>,
#  <일>3</일>,
#  <일>4</일>,
#  <일>4</일>,
#  <일>4</일>,
#  <일>4</일>,
#  <일>4</일>,
#  <일>5</일>,
#  <일>6</일>,
#  <일>6</일>,
#  <일>6</일>,
#  <일>7</일>,
#  <일>7</일>,
#  <일>8</일>,
#  <일>8</일>,
#  <일>8</일>,
#  <일>8</일>,
#  <일>10</일>,
#  <일>10</일>,
#  <일>11</일>,
#  <일>11</일>,
#  <일>12</일>,
#  <일>12</일>,
#  <일>12</일>,
#  <일>13</일>,
#  <일>13</일>,
#  <일>14</일>,
#  <일>14</일>,
#  <일>14</일>,
#  <일>14</일>,
#  <일>14</일>,
#  <일>15</일>,
#  <일>16</일>,
#  <일>17</일>,
#  <일>17</일>,
#  <일>17</일>,
#  <일>18</일>,
#  <일>19</일>,
#  <일>19</일>,
#  <일>21</일>,
#  <일>21</일>,
#  <일>22</일>,
#  <일>22</일>,
#  <일>22</일>,
#  <일>22</일>,
#  <일>22</일>,
#  <일>22</일>,
#  <일>25</일>,
#  <일>25</일>,
#  <일>27</일>,
#  <일>27</일>,
#  <일>27</일>,
#  <일>31</일>,
#  <일>31</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>1</일>,
#  <일>3</일>,
#  <일>3</일>,
#  <일>3</일>,
#  <일>3</일>,
#  <일>4</일>,
# ...

# %%
ymd_d_L = []
for n in ymd_d :
    ymd_d_L.append(n.text)

# %%
type(ymd_d_L)
# Out:
# list

# %%
len(ymd_y_L)
# Out:
# 481

# %%
type(ymd_y_L[0])
# Out:
# str

# %% [raw]
# ymdymd = []
# for i in range (len(ymd_y_L)) :
#     df['연월일'] = ymd_y_L[i] + ymd_m_L[i] + ymd_d_L[i]
#     i += 1

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13696\1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
dong = soup.select('법정동')

# %%
dong

# %%
dong_L = []
for n in dong :
    dong_L.append(n.text)

# %%
dong_L

# %%
am_m=soup.select('보증금액')

# %%
am_m_L = []
for n in am_m :
    am_m_L.append(n.text)

# %%
apt=soup.select('아파트')

# %%
apt_L = []
for n in apt :
    apt_L.append(n.text)

# %%
mo_rent=soup.select('월세금액')

# %%
mo_rent_L = []
for n in mo_rent :
    mo_rent_L.append(n.text)

# %%
area=soup.select('전용면적')

# %%
area_L = []
for n in area :
    area_L.append(n.text)

# %%
floor=soup.select('층')

# %%
floor_L = []
for n in floor :
    floor_L.append(n.text)

# %%
#하나씩 뽑은 값을 하나의 리스트로 합치기

data=[]
for i in range(len(year)) :
    temp =[]
    temp.append(year[i].text)
    temp.append(dong[i].text)
    temp.append(am_m[i].text.strip())
    temp.append(apt[i].text)
    temp.append(mo_rent[i].text.strip())
    temp.append(area[i].text)
    temp.append(floor[i].text)
    data.append(temp)

# %%
data[0]

# %% [raw]
# data  = list(zip(name_L, L2, where_L))

# %%
import pandas as pd

# %%
df = pd.DataFrame(data, columns=['건축년도','법정동','보증금액','아파트','월세금액','전용면적','층'])

# %% [raw]
# 건축년도 / 연월일 / 법정동 / 보증금액 / 아파트 / 월세금액 / 전용면적 / 층

# %%
df

# %%
#해답

# %%
year = soup.select
month

# %%
data = []
for i in range (len(year)) : 
    temp =[]

# %% [markdown]
# ----------------------------------------------

# %%
#데이터 하나를 다가져와서 필요한 것만 쓰거나 필요한 것 외에 버리기

# %%
soup.items()[0]

# %%
col_names = []
for item in soup.items()[0] :
    #print(item.name)
    
    #print('--')
    col_names.append(item.name)

# %%
col_names
# Out:
# ['갱신요구권사용',
#  '건축년도',
#  '계약구분',
#  '계약기간',
#  '년',
#  '법정동',
#  '보증금액',
#  '아파트',
#  '월',
#  '월세금액',
#  '일',
#  '전용면적',
#  '종전계약보증금',
#  '종전계약월세',
#  '지번',
#  '지역코드',
#  '층']

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text.strip())
        #print(t.text)
        #print('------')  
    data.append(temp)

# %%
data
# Out:
# [['',
#   '2000',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '31,000',
#   '동아2',
#   '10',
#   '0',
#   '2',
#   '59.595',
#   '',
#   '',
#   '644',
#   '11530',
#   '4'],
#  ['',
#   '2001',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '25,000',
#   '대림3',
#   '10',
#   '120',
#   '3',
#   '84.51',
#   '',
#   '',
#   '691',
#   '11530',
#   '13'],
#  ['',
#   '2011',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '120,000',
#   '디큐브시티',
#   '10',
#   '0',
#   '4',
#   '128.41',
#   '',
#   '',
#   '692',
#   '11530',
#   '34'],
#  ['',
#   '2004',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '60,000',
#   '대림e-편한세상7',
#   '10',
#   '0',
#   '4',
#   '84.928',
#   '',
#   '',
#   '649',
#   '11530',
#   '3'],
#  ['',
#   '1996',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '48,000',
#   '우성2',
#   '10',
#   '0',
#   '4',
#   '84.82',
#   '',
#   '',
#   '639',
#   '11530',
#   '4'],
#  ['',
#   '1999',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '10,000',
#   '현대홈타운아파트',
#   '10',
# ...

# %%
df = pd.DataFrame(data, columns = col_names)

# %%
df
# Out:
#     갱신요구권사용  건축년도 계약구분 계약기간     년   법정동     보증금액              아파트   월 월세금액  \
# 0            2000            2022  신도림동   31,000              동아2  10    0
# 1            2001            2022  신도림동   25,000              대림3  10  120
# 2            2011            2022  신도림동  120,000            디큐브시티  10    0
# 3            2004            2022  신도림동   60,000        대림e-편한세상7  10    0
# 4            1996            2022  신도림동   48,000              우성2  10    0
# ..      ...   ...  ...  ...   ...   ...      ...              ...  ..  ...
# 476          2014            2022   천왕동   57,000        천왕연지타운2단지  10    0
# 477          2019            2022    항동   50,000        한양수자인에듀힐즈  10    0
# 478          2019            2022    항동   27,500          하버라인4단지  10    0
# 479          2019            2022    항동   55,000  항동중흥에스클래스베르데카운티  10    0
# 480          2020            2022    항동   35,000       우남퍼스트빌더센트럴  10    0
#
#       일     전용면적 종전계약보증금 종전계약월세     지번   지역코드   층
# ...

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# 갱신요구권사용    0
# 건축년도       0
# 계약구분       0
# 계약기간       0
# 년          0
# 법정동        0
# 보증금액       0
# 아파트        0
# 월          0
# 월세금액       0
# 일          0
# 전용면적       0
# 종전계약보증금    0
# 종전계약월세     0
# 지번         0
# 지역코드       0
# 층          0
# dtype: int64

# %%
df = df.dropna(axis= 1) #열의 결측치가 있으면 제거!

# %%
df['계약일'] = df['년'] + df['월'].str.zfill(2)+ df['일'].str.zfill(2) 
#계약일 항목추가

# %%
df
# Out:
#     갱신요구권사용  건축년도 계약구분 계약기간     년   법정동     보증금액              아파트   월 월세금액  \
# 0            2000            2022  신도림동   31,000              동아2  10    0
# 1            2001            2022  신도림동   25,000              대림3  10  120
# 2            2011            2022  신도림동  120,000            디큐브시티  10    0
# 3            2004            2022  신도림동   60,000        대림e-편한세상7  10    0
# 4            1996            2022  신도림동   48,000              우성2  10    0
# ..      ...   ...  ...  ...   ...   ...      ...              ...  ..  ...
# 476          2014            2022   천왕동   57,000        천왕연지타운2단지  10    0
# 477          2019            2022    항동   50,000        한양수자인에듀힐즈  10    0
# 478          2019            2022    항동   27,500          하버라인4단지  10    0
# 479          2019            2022    항동   55,000  항동중흥에스클래스베르데카운티  10    0
# 480          2020            2022    항동   35,000       우남퍼스트빌더센트럴  10    0
#
#       일     전용면적 종전계약보증금 종전계약월세     지번   지역코드   층       계약일
# ...

# %% [raw]
# 구로동 11530 / 22년 6월 ~10 월까지
