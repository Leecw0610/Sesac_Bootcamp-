# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('elevInfo.csv', encoding='euc-kr')

# %%
#검사기관 검사일자 합격

# %%
df

# %%
http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorView?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&elevator_no=0081201

# %%
df['elevatorNo']=df['elevatorNo'].astype(str).str.zfill(7)

# %%
df

# %%
df['elevatorNo']

# %%
for no in df['elevatorNo'] :
    elevatorNo=str(no).zfill(7)

# %%
df['elevatorNo'][i]

# %%
for i in 200 :
    df['elevatorNo'][i]

# %%
df['elevatorNo']=df['elevatorNo'].astype(str).str.zfill(7)

data = []


for i in tqdm(range(200)):
    elevator_no = df['elevatorNo'][i] 
    url = 'http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorView'
    serviceKey = '3kygm0EzV/eG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g=='
    
    params = {'serviceKey' : serviceKey, 'elevator_no' : elevator_no }
    req = requests.get(url, params=params,verify=False)
    soup = BeautifulSoup(req.text,'lxml')
    col_list = ['lastinspctDe', 'inspctInstt', 'lastResultNm']

    for item in soup :
        temp = []
        for col in col_list :
            try :
                temp.append(item.select(col)[0].text)
            except :
                temp.append('')
        data.append(temp)

# %%
data

# %%
type(data)

# %%
data[1::2]

# %%
req.text

# %%
##해답

# %%
df['elevatorNo']=df['elevatorNo'].astype(str).str.zfill(7)

data = []


for i in tqdm(range(200)):
    elevator_no = df['elevatorNo'][i] 
    url = 'http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorView'
    serviceKey = '3kygm0EzV/eG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g=='
    
    params = {'serviceKey' : serviceKey, 'elevator_no' : elevator_no }
    req = requests.get(url, params=params,verify=False)
    soup = BeautifulSoup(req.text,'lxml')
    col_list = ['lastinspctDe', 'inspctInstt', 'lastResultNm']
    
    temp =[]
    
    temp.append(i)
    temp.append(soup.select('lastinspctDe')[0].text)
    try :
        temp.append(soup.select('lastinspctDe')[0].text)
    except :
        temp.append('')
    temp.append(soup.select('inspctInstt')[0].text)
    try :
        temp.append(soup.select('inspctInstt')[0].text)
    except :
        temp.append('')
    temp.append(soup.select('lastResultNm')[0].text)
    try :
        temp.append(soup.select('lastResultNm')[0].text)
    except :
        temp.append('')
    
    data.append(temp)
# Out:
#  43%|███████████████████████████████▍                                         | 86/200 [03:23<04:29,  2.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 6>()
#       9 serviceKey = '3kygm0EzV/eG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g=='
#      11 params = {'serviceKey' : serviceKey, 'elevator_no' : elevator_no }
# ---> 12 req = requests.get(url, params=params,verify=False)
#      13 soup = BeautifulSoup(req.text,'lxml')
#      14 col_list = ['lastinspctDe', 'inspctInstt', 'lastResultNm']
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ...

# %%
df
# Out:
#                   address1    address2         buldNm elevatorNo elvtrStts  \
# 0         서울특별시 은평구 연서로 71       (역촌동)         (재)살림이    0081201       운행중
# 1      서울특별시 은평구 통일로71길 16       (대조동)     (주)KT 은평지사    0042569       운행중
# 2      서울특별시 은평구 통일로71길 16       (대조동)     (주)KT 은평지사    0042570       운행중
# 3    서울특별시 은평구 은평로13길 12-1  해명빌딩 (녹번동)  (주)녹번해명(해명빌딩)    0104893       운행중
# 4    서울특별시 은평구 은평로13길 12-1  해명빌딩 (녹번동)  (주)녹번해명(해명빌딩)    0004213       운행중
# ..                     ...         ...            ...        ...       ...
# 195    서울특별시 은평구 수색동 115-5       (수색동)        DMC파인시티    0155005       운행중
# 196    서울특별시 은평구 수색동 115-5       (수색동)        DMC파인시티    0154984       운행중
# 197    서울특별시 은평구 수색동 115-5       (수색동)        DMC파인시티    0154985       운행중
# 198    서울특별시 은평구 수색동 115-5       (수색동)        DMC파인시티    0155230       운행중
# 199    서울특별시 은평구 수색동 115-5       (수색동)        DMC파인시티    0155231       운행중
#
#     lastInspctDe liveLoad manufacturerName manufacturerTelno
# ...

# %%
df2 = pd.read_csv('elevInspect.csv', encoding = 'euckr')

# %%
df2
# Out:
#      elevatorNo lastInspctDe       inspctInstt lastResultNm
# 0         81201   2022-05-24  한국승강기안전공단 서울서부지사           합격
# 1         42569   2022-10-11  한국승강기안전공단 서울서부지사           합격
# 2         42570   2022-10-11  한국승강기안전공단 서울서부지사        조건부합격
# 3        104893   2022-11-03  한국승강기안전공단 서울서부지사        조건부합격
# 4          4213   2022-11-03  한국승강기안전공단 서울서부지사        조건부합격
# ..          ...          ...               ...          ...
# 195      155005   2022-07-11  한국승강기안전공단 서울서부지사        보완후합격
# 196      154984   2022-06-15  한국승강기안전공단 서울서부지사        보완후합격
# 197      154985   2022-06-15  한국승강기안전공단 서울서부지사        보완후합격
# 198      155230   2022-10-31  한국승강기안전공단 서울서부지사        보완후합격
# 199      155231   2022-10-31  한국승강기안전공단 서울서부지사        보완후합격
#
# [200 rows x 4 columns]

# %%
df2['elevatorNo'] = df2['elevatorNo'].astype(str).str.zfill(7)

# %%
df_all =pd.merge(df, df2, on='elevatorNo')

# %%
df_all.head(5)
# Out:
#                 address1    address2         buldNm elevatorNo elvtrStts  \
# 0       서울특별시 은평구 연서로 71       (역촌동)         (재)살림이    0081201       운행중
# 1    서울특별시 은평구 통일로71길 16       (대조동)     (주)KT 은평지사    0042569       운행중
# 2    서울특별시 은평구 통일로71길 16       (대조동)     (주)KT 은평지사    0042570       운행중
# 3  서울특별시 은평구 은평로13길 12-1  해명빌딩 (녹번동)  (주)녹번해명(해명빌딩)    0104893       운행중
# 4  서울특별시 은평구 은평로13길 12-1  해명빌딩 (녹번동)  (주)녹번해명(해명빌딩)    0004213       운행중
#
#   lastInspctDe_x liveLoad manufacturerName manufacturerTelno lastInspctDe_y  \
# 0     2022-05-24   550 KG     엘지산전(주) 창원공장      055-269-4114     2022-05-24
# 1     2022-10-11  1150 KG  오티스엘리베이터(유)창원공장      055-289-8235     2022-10-11
# 2     2022-10-11  1150 KG  오티스엘리베이터(유)창원공장      055-289-8235     2022-10-11
# 3     2022-11-03  1150 KG       현대엘리베이터(주)      043-722-1000     2022-11-03
# 4     2022-11-03  2000 KG       영진엘리베이터(주)      032-815-7871     2022-11-03
#
#         inspctInstt lastResultNm
# 0  한국승강기안전공단 서울서부지사           합격
# ...
